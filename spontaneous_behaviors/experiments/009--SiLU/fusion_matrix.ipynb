# %%
import numpy as np

# path to the saved matrices
mat_path = "/home/maria/Science/models/saved_syllable_pc_model/model_matrices.npz"

data = np.load(mat_path)

print("Available matrices:")
for k in data.files:
    print(k, data[k].shape)

# example: fusion layer
fusion_weight = data["fusion.0.weight"]
fusion_bias = data["fusion.0.bias"]

print("\nFusion weight shape:", fusion_weight.shape)
print("Fusion bias shape:", fusion_bias.shape)

print("\nFusion weight:")
print(fusion_weight)

print("\nFusion bias:")
print(fusion_bias)
# Out:
# Available matrices:
# syll_embedding.weight (45, 16)
# pc_encoder.0.weight (128, 10)
# pc_encoder.0.bias (128,)
# pc_encoder.2.weight (128, 128)
# pc_encoder.2.bias (128,)
# fusion.0.weight (128, 144)
# fusion.0.bias (128,)
# predict_next_pc.weight (10, 128)
# predict_next_pc.bias (10,)
#
# Fusion weight shape: (128, 144)
# Fusion bias shape: (128,)
#
# Fusion weight:
# [[ 0.04758331  0.07735546 -0.04812855 ... -0.04560477  0.05128273
#    0.01875653]
#  [ 0.06468455  0.1362355  -0.0280986  ... -0.03948968 -0.05115163
#    0.01404961]
#  [ 0.03656302 -0.14590788  0.01737212 ... -0.0340177  -0.07990182
#   -0.03680725]
#  ...
#  [-0.03288109  0.09930587  0.07369896 ... -0.02019889  0.05111982
#    0.0629449 ]
#  [ 0.01249978  0.02985085 -0.08273906 ...  0.03805626  0.01721761
#   -0.02572165]
#  [ 0.00281566 -0.06772676  0.06772633 ...  0.07332207  0.04229333
#    0.08346844]]
#
# Fusion bias:
# [ 8.85260403e-02 -2.39211079e-02  6.86383322e-02  5.08550592e-02
# ...

# %%
fusion_weight.shape
# Out:
# (128, 144)
