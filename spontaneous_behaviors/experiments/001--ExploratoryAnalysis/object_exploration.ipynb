# %%
# =========================================
# 0. Imports
# =========================================
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt

from pathlib import Path

# Optional
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


# =========================================
# 1. Paths
# =========================================
behavior_path = Path("/home/maria/Science/data/spontaneous_behaviors/object_interaction-behavior.parquet")
neural_path   = Path("/home/maria/Science/data/spontaneous_behaviors/object_interaction-neural.h5")


# =========================================
# 2. Load behavior data
# =========================================
behavior = pd.read_parquet(behavior_path)

print("Behavior shape:", behavior.shape)
print("\nBehavior columns:")
print(behavior.columns.tolist())

display(behavior.head())
display(behavior.describe(include="all").T.head(50))


# =========================================
# 3. Inspect behavior missingness
# =========================================
missing_behavior = behavior.isna().mean().sort_values(ascending=False)
display(missing_behavior.head(30))

plt.figure(figsize=(8, 4))
missing_behavior.head(30).plot(kind="bar")
plt.title("Top 30 behavior columns by missing fraction")
plt.ylabel("Missing fraction")
plt.tight_layout()
plt.show()


# =========================================
# 4. Load neural H5 structure
# =========================================
def print_h5_structure(name, obj):
    if isinstance(obj, h5py.Dataset):
        print(f"DATASET: {name}, shape={obj.shape}, dtype={obj.dtype}")
    else:
        print(f"GROUP:   {name}")

with h5py.File(neural_path, "r") as f:
    print("H5 structure:")
    f.visititems(print_h5_structure)
# Out:
# Behavior shape: (7776306, 94)
#
# Behavior columns:
# ['session', 'timestamp', 'MoSeq syllable', 'shMoSeq state', '3D keypoint: spine_low (x)', '3D keypoint: spine_low (y)', '3D keypoint: spine_low (z)', '3D keypoint: tail_base (x)', '3D keypoint: tail_base (y)', '3D keypoint: tail_base (z)', '3D keypoint: spine_mid (x)', '3D keypoint: spine_mid (y)', '3D keypoint: spine_mid (z)', '3D keypoint: spine_high (x)', '3D keypoint: spine_high (y)', '3D keypoint: spine_high (z)', '3D keypoint: left_ear (x)', '3D keypoint: left_ear (y)', '3D keypoint: left_ear (z)', '3D keypoint: right_ear (x)', '3D keypoint: right_ear (y)', '3D keypoint: right_ear (z)', '3D keypoint: forehead (x)', '3D keypoint: forehead (y)', '3D keypoint: forehead (z)', '3D keypoint: nose_tip (x)', '3D keypoint: nose_tip (y)', '3D keypoint: nose_tip (z)', '3D keypoint: left_forepaw (x)', '3D keypoint: left_forepaw (y)', '3D keypoint: left_forepaw (z)', '3D keypoint: right_forepaw (x)', '3D keypoint: right_forepaw (y)', '3D keypoint: right_forepaw (z)', '3D keypoint: left_hindpaw_back (x)', '3D keypoint: left_hindpaw_back (y)', '3D keypoint: left_hindpaw_back (z)', '3D keypoint: left_hindpaw_front (x)', '3D keypoint: left_hindpaw_front (y)', '3D keypoint: left_hindpaw_front (z)', '3D keypoint: right_hindpaw_back (x)', '3D keypoint: right_hindpaw_back (y)', '3D keypoint: right_hindpaw_back (z)', '3D keypoint: right_hindpaw_front (x)', '3D keypoint: right_hindpaw_front (y)', '3D keypoint: right_hindpaw_front (z)', '2D keypoint: spine_low (x)', '2D keypoint: spine_low (y)', '2D keypoint: tail_base (x)', '2D keypoint: tail_base (y)', '2D keypoint: spine_mid (x)', '2D keypoint: spine_mid (y)', '2D keypoint: spine_high (x)', '2D keypoint: spine_high (y)', '2D keypoint: left_ear (x)', '2D keypoint: left_ear (y)', '2D keypoint: right_ear (x)', '2D keypoint: right_ear (y)', '2D keypoint: forehead (x)', '2D keypoint: forehead (y)', '2D keypoint: nose_tip (x)', '2D keypoint: nose_tip (y)', '2D keypoint: left_forepaw (x)', '2D keypoint: left_forepaw (y)', '2D keypoint: right_forepaw (x)', '2D keypoint: right_forepaw (y)', '2D keypoint: left_hindpaw_back (x)', '2D keypoint: left_hindpaw_back (y)', '2D keypoint: left_hindpaw_front (x)', '2D keypoint: left_hindpaw_front (y)', '2D keypoint: right_hindpaw_back (x)', '2D keypoint: right_hindpaw_back (y)', '2D keypoint: right_hindpaw_front (x)', '2D keypoint: right_hindpaw_front (y)', 'object bbox: object0 (x1)', 'object bbox: object0 (y1)', 'object bbox: object0 (x2)', 'object bbox: object0 (y2)', 'object bbox: object1 (x1)', 'object bbox: object1 (y1)', 'object bbox: object1 (x2)', 'object bbox: object1 (y2)', 'object bbox: object2 (x1)', 'object bbox: object2 (y1)', 'object bbox: object2 (x2)', 'object bbox: object2 (y2)', 'object bbox: object3 (x1)', 'object bbox: object3 (y1)', 'object bbox: object3 (x2)', 'object bbox: object3 (y2)', 'object bbox: object4 (x1)', 'object bbox: object4 (y1)', 'object bbox: object4 (x2)', 'object bbox: object4 (y2)']
#                session  timestamp  MoSeq syllable  shMoSeq state  \
# 0  subject6_recording0   0.000000               0              3
# 1  subject6_recording0   0.008333               0              3
# 2  subject6_recording0   0.016667               0              3
# 3  subject6_recording0   0.025000               0              3
# 4  subject6_recording0   0.033333               0              3
#
#    3D keypoint: spine_low (x)  3D keypoint: spine_low (y)  \
# 0                  100.619087                  -63.385349
# 1                  100.696999                  -63.385349
# 2                  100.696999                  -63.385349
# 3                  100.619087                  -63.385349
# 4                  100.174454                  -63.299976
#
#    3D keypoint: spine_low (z)  3D keypoint: tail_base (x)  \
# 0                   14.261245                   97.691963
# 1                   14.211292                   97.691963
# 2                   14.261245                   97.691963
# 3                   14.521353                   97.795975
# 4                   14.904133                   97.812279
#
#    3D keypoint: tail_base (y)  3D keypoint: tail_base (z)  ...  \
# 0                  -61.625576                    2.521190  ...
# 1                  -61.625576                    2.521190  ...
# 2                  -61.625576                    1.983366  ...
# 3                  -61.684544                    1.983366  ...
# 4                  -61.684544                    1.983366  ...
#
#    object bbox: object2 (x2)  object bbox: object2 (y2)  \
# 0                       <NA>                       <NA>
# 1                       <NA>                       <NA>
# 2                       <NA>                       <NA>
# 3                       <NA>                       <NA>
# 4                       <NA>                       <NA>
#
#    object bbox: object3 (x1)  object bbox: object3 (y1)  \
# 0                       <NA>                       <NA>
# 1                       <NA>                       <NA>
# 2                       <NA>                       <NA>
# 3                       <NA>                       <NA>
# 4                       <NA>                       <NA>
#
#    object bbox: object3 (x2)  object bbox: object3 (y2)  \
# 0                       <NA>                       <NA>
# 1                       <NA>                       <NA>
# 2                       <NA>                       <NA>
# 3                       <NA>                       <NA>
# 4                       <NA>                       <NA>
#
#    object bbox: object4 (x1)  object bbox: object4 (y1)  \
# 0                       <NA>                       <NA>
# 1                       <NA>                       <NA>
# 2                       <NA>                       <NA>
# 3                       <NA>                       <NA>
# 4                       <NA>                       <NA>
#
#    object bbox: object4 (x2)  object bbox: object4 (y2)
# 0                       <NA>                       <NA>
# 1                       <NA>                       <NA>
# 2                       <NA>                       <NA>
# 3                       <NA>                       <NA>
# 4                       <NA>                       <NA>
#
# [5 rows x 94 columns]
#                                           count unique                  top  \
# session                                 7776306     18  subject0_recording0
# timestamp                             7776306.0    NaN                  NaN
# MoSeq syllable                        7776306.0    NaN                  NaN
# shMoSeq state                         7219672.0   <NA>                 <NA>
# 3D keypoint: spine_low (x)            7776306.0    NaN                  NaN
# 3D keypoint: spine_low (y)            7776306.0    NaN                  NaN
# 3D keypoint: spine_low (z)            7776306.0    NaN                  NaN
# 3D keypoint: tail_base (x)            7776306.0    NaN                  NaN
# 3D keypoint: tail_base (y)            7776306.0    NaN                  NaN
# 3D keypoint: tail_base (z)            7776306.0    NaN                  NaN
# 3D keypoint: spine_mid (x)            7776306.0    NaN                  NaN
# 3D keypoint: spine_mid (y)            7776306.0    NaN                  NaN
# 3D keypoint: spine_mid (z)            7776306.0    NaN                  NaN
# 3D keypoint: spine_high (x)           7776306.0    NaN                  NaN
# 3D keypoint: spine_high (y)           7776306.0    NaN                  NaN
# 3D keypoint: spine_high (z)           7776306.0    NaN                  NaN
# 3D keypoint: left_ear (x)             7776306.0    NaN                  NaN
# 3D keypoint: left_ear (y)             7776306.0    NaN                  NaN
# 3D keypoint: left_ear (z)             7776306.0    NaN                  NaN
# 3D keypoint: right_ear (x)            7776306.0    NaN                  NaN
# 3D keypoint: right_ear (y)            7776306.0    NaN                  NaN
# 3D keypoint: right_ear (z)            7776306.0    NaN                  NaN
# 3D keypoint: forehead (x)             7776306.0    NaN                  NaN
# 3D keypoint: forehead (y)             7776306.0    NaN                  NaN
# 3D keypoint: forehead (z)             7776306.0    NaN                  NaN
# 3D keypoint: nose_tip (x)             7776306.0    NaN                  NaN
# 3D keypoint: nose_tip (y)             7776306.0    NaN                  NaN
# 3D keypoint: nose_tip (z)             7776306.0    NaN                  NaN
# 3D keypoint: left_forepaw (x)         7776306.0    NaN                  NaN
# 3D keypoint: left_forepaw (y)         7776306.0    NaN                  NaN
# 3D keypoint: left_forepaw (z)         7776306.0    NaN                  NaN
# 3D keypoint: right_forepaw (x)        7776306.0    NaN                  NaN
# 3D keypoint: right_forepaw (y)        7776306.0    NaN                  NaN
# 3D keypoint: right_forepaw (z)        7776306.0    NaN                  NaN
# 3D keypoint: left_hindpaw_back (x)    7776306.0    NaN                  NaN
# 3D keypoint: left_hindpaw_back (y)    7776306.0    NaN                  NaN
# 3D keypoint: left_hindpaw_back (z)    7776306.0    NaN                  NaN
# 3D keypoint: left_hindpaw_front (x)   7776306.0    NaN                  NaN
# 3D keypoint: left_hindpaw_front (y)   7776306.0    NaN                  NaN
# 3D keypoint: left_hindpaw_front (z)   7776306.0    NaN                  NaN
# 3D keypoint: right_hindpaw_back (x)   7776306.0    NaN                  NaN
# 3D keypoint: right_hindpaw_back (y)   7776306.0    NaN                  NaN
# 3D keypoint: right_hindpaw_back (z)   7776306.0    NaN                  NaN
# 3D keypoint: right_hindpaw_front (x)  7776306.0    NaN                  NaN
# 3D keypoint: right_hindpaw_front (y)  7776306.0    NaN                  NaN
# 3D keypoint: right_hindpaw_front (z)  7776306.0    NaN                  NaN
# 2D keypoint: spine_low (x)            7776306.0    NaN                  NaN
# 2D keypoint: spine_low (y)            7776306.0    NaN                  NaN
# 2D keypoint: tail_base (x)            7776306.0    NaN                  NaN
# 2D keypoint: tail_base (y)            7776306.0    NaN                  NaN
#
#                                         freq        mean          std  \
# session                               432017         NaN          NaN
# timestamp                                NaN  1800.06665  1039.271484
# MoSeq syllable                           NaN   13.338182    11.915028
# shMoSeq state                           <NA>    1.450627     1.428459
# 3D keypoint: spine_low (x)               NaN  -10.799395     78.46756
# 3D keypoint: spine_low (y)               NaN    8.439825    77.999077
# 3D keypoint: spine_low (z)               NaN   16.138968     2.607826
# 3D keypoint: tail_base (x)               NaN  -11.226411     78.67157
# 3D keypoint: tail_base (y)               NaN    8.106642    78.355232
# 3D keypoint: tail_base (z)               NaN    5.003511     3.097417
# 3D keypoint: spine_mid (x)               NaN   -9.902548    76.211792
# 3D keypoint: spine_mid (y)               NaN    9.425166    75.027901
# 3D keypoint: spine_mid (z)               NaN   34.241482     3.146055
# 3D keypoint: spine_high (x)              NaN    -8.74516    74.193726
# 3D keypoint: spine_high (y)              NaN   10.572235    72.209694
# 3D keypoint: spine_high (z)              NaN   32.966614     4.474632
# 3D keypoint: left_ear (x)                NaN   -9.292524    73.135391
# 3D keypoint: left_ear (y)                NaN   11.652659    71.638123
# 3D keypoint: left_ear (z)                NaN   34.233421     5.936493
# 3D keypoint: right_ear (x)               NaN   -7.178122    74.185379
# 3D keypoint: right_ear (y)               NaN   11.079821    71.169395
# 3D keypoint: right_ear (z)               NaN   33.554478      5.94007
# 3D keypoint: forehead (x)                NaN   -8.134053    74.446701
# 3D keypoint: forehead (y)                NaN   12.184091    72.209358
# 3D keypoint: forehead (z)                NaN   23.894938     8.896871
# 3D keypoint: nose_tip (x)                NaN   -8.877723    76.499741
# 3D keypoint: nose_tip (y)                NaN   11.979835    74.213699
# 3D keypoint: nose_tip (z)                NaN   13.747684    12.062937
# 3D keypoint: left_forepaw (x)            NaN    -9.93977     76.43911
# 3D keypoint: left_forepaw (y)            NaN   11.291303    74.654175
# 3D keypoint: left_forepaw (z)            NaN    2.518033     6.466925
# 3D keypoint: right_forepaw (x)           NaN   -8.824939    76.775291
# 3D keypoint: right_forepaw (y)           NaN   10.735525    74.264137
# 3D keypoint: right_forepaw (z)           NaN    2.362411     7.235195
# 3D keypoint: left_hindpaw_back (x)       NaN  -10.749123    76.841919
# 3D keypoint: left_hindpaw_back (y)       NaN   10.531276    76.446938
# 3D keypoint: left_hindpaw_back (z)       NaN    2.396592     2.143913
# 3D keypoint: left_hindpaw_front (x)      NaN  -10.537489    76.838882
# 3D keypoint: left_hindpaw_front (y)      NaN   11.251136    76.380966
# 3D keypoint: left_hindpaw_front (z)      NaN    1.353002     2.123074
# 3D keypoint: right_hindpaw_back (x)      NaN   -9.686703     77.19046
# 3D keypoint: right_hindpaw_back (y)      NaN    9.090416    75.503014
# 3D keypoint: right_hindpaw_back (z)      NaN    1.983721      2.39977
# 3D keypoint: right_hindpaw_front (x)     NaN   -9.037372    77.391899
# 3D keypoint: right_hindpaw_front (y)     NaN    8.941612    75.114136
# 3D keypoint: right_hindpaw_front (z)     NaN    1.134131     1.763042
# 2D keypoint: spine_low (x)               NaN  569.808105   252.497345
# 2D keypoint: spine_low (y)               NaN  541.473267   254.149399
# 2D keypoint: tail_base (x)               NaN  570.142639   259.177917
# 2D keypoint: tail_base (y)               NaN  541.135254   260.437683
#
#                                              min         25%         50%  \
# session                                      NaN         NaN         NaN
# timestamp                                    0.0  900.033325  1800.06665
# MoSeq syllable                               0.0         1.0         9.0
# shMoSeq state                                0.0         0.0         1.0
# 3D keypoint: spine_low (x)            -149.25882  -78.412209  -17.769707
# 3D keypoint: spine_low (y)           -127.678131  -60.900993    3.626701
# 3D keypoint: spine_low (z)              4.547261   14.413071   15.691076
# 3D keypoint: tail_base (x)           -147.357025  -78.952324  -18.318374
# 3D keypoint: tail_base (y)           -124.125336  -61.338723    2.603403
# 3D keypoint: tail_base (z)              -2.30025    2.922358     4.17941
# 3D keypoint: spine_mid (x)           -141.249832  -75.772903  -17.220903
# 3D keypoint: spine_mid (y)           -118.284065  -58.837915     4.34973
# 3D keypoint: spine_mid (z)             19.871162   32.290138   33.905575
# 3D keypoint: spine_high (x)          -132.643845  -73.767626  -15.326327
# 3D keypoint: spine_high (y)          -115.346794  -55.596216       1.572
# 3D keypoint: spine_high (z)           -15.086791   30.423959   32.298443
# 3D keypoint: left_ear (x)            -143.328842  -75.021135  -15.721581
# 3D keypoint: left_ear (y)            -127.022079  -53.650261    3.270019
# 3D keypoint: left_ear (z)              11.559663   31.111258   33.858494
# 3D keypoint: right_ear (x)           -143.182495   -70.67853  -14.815725
# 3D keypoint: right_ear (y)           -123.814095  -52.955814    3.180879
# 3D keypoint: right_ear (z)             -1.914352   30.397436   33.246105
# 3D keypoint: forehead (x)            -141.756348  -75.350132  -15.388596
# 3D keypoint: forehead (y)            -117.801704  -52.658556    3.874808
# 3D keypoint: forehead (z)             -22.188303   17.921003   22.016406
# 3D keypoint: nose_tip (x)            -151.246506  -76.846817  -15.866334
# 3D keypoint: nose_tip (y)            -127.930885  -53.411276    4.162929
# 3D keypoint: nose_tip (z)             -73.545074    5.474657   10.508229
# 3D keypoint: left_forepaw (x)        -158.306717  -79.469093  -17.352546
# 3D keypoint: left_forepaw (y)        -128.430099  -56.716534    2.610784
# 3D keypoint: left_forepaw (z)         -82.059273    0.183418    0.789349
# 3D keypoint: right_forepaw (x)       -153.646881  -76.181137  -17.506716
# 3D keypoint: right_forepaw (y)       -131.692032  -56.471286    1.893494
# 3D keypoint: right_forepaw (z)        -82.752281    0.056667    0.661144
# 3D keypoint: left_hindpaw_back (x)   -148.863098  -75.319992  -18.777608
# 3D keypoint: left_hindpaw_back (y)    -126.12706  -57.093933    5.623108
# 3D keypoint: left_hindpaw_back (z)    -38.355652    1.274114    2.042974
# 3D keypoint: left_hindpaw_front (x)  -152.457245  -74.738594  -17.714853
# 3D keypoint: left_hindpaw_front (y)  -129.063416  -55.829465    4.730921
# 3D keypoint: left_hindpaw_front (z)   -54.990929    0.493295    0.978203
# 3D keypoint: right_hindpaw_back (x)   -149.39328      -77.43  -16.526014
# 3D keypoint: right_hindpaw_back (y)  -126.545044  -58.101915    4.446961
# 3D keypoint: right_hindpaw_back (z)   -29.075912    0.943588    1.750536
# 3D keypoint: right_hindpaw_front (x) -151.374802  -75.423727  -14.306165
# 3D keypoint: right_hindpaw_front (y) -130.308533   -57.65443    2.929507
# 3D keypoint: right_hindpaw_front (z)  -52.293522    0.297847      0.8339
# 2D keypoint: spine_low (x)            146.682266  346.911156  548.621063
# 2D keypoint: spine_low (y)             22.801888   324.45121  562.475128
# 2D keypoint: tail_base (x)            141.176636   343.27227  547.952148
# 2D keypoint: tail_base (y)               1.77197   318.60569  560.305603
#
#                                               75%          max
# session                                       NaN          NaN
# timestamp                             2700.100098  3600.133301
# MoSeq syllable                               22.0         49.0
# shMoSeq state                                 3.0          4.0
# 3D keypoint: spine_low (x)              55.308322   152.484589
# 3D keypoint: spine_low (y)              69.538963   180.327042
# 3D keypoint: spine_low (z)              17.305684    40.314423
# 3D keypoint: tail_base (x)              55.104523    153.87912
# 3D keypoint: tail_base (y)              69.626364   181.506348
# 3D keypoint: tail_base (z)               6.138616    35.932098
# 3D keypoint: spine_mid (x)              55.949741   149.912018
# 3D keypoint: spine_mid (y)              66.784767   172.214462
# 3D keypoint: spine_mid (z)               35.76556    65.009438
# 3D keypoint: spine_high (x)             55.189697   144.043427
# 3D keypoint: spine_high (y)             69.246431    166.85762
# 3D keypoint: spine_high (z)             34.525027    89.925957
# 3D keypoint: left_ear (x)               54.055759   152.097153
# 3D keypoint: left_ear (y)               70.333143    174.79332
# 3D keypoint: left_ear (z)               36.761932    99.693283
# 3D keypoint: right_ear (x)               56.07793   158.272598
# 3D keypoint: right_ear (y)              69.476273   179.452988
# 3D keypoint: right_ear (z)              36.155643   101.763069
# 3D keypoint: forehead (x)               54.731766   152.585541
# 3D keypoint: forehead (y)               71.692104   178.699188
# 3D keypoint: forehead (z)               27.343777   112.042145
# 3D keypoint: nose_tip (x)               55.040488   163.576309
# 3D keypoint: nose_tip (y)               72.462185   186.845642
# 3D keypoint: nose_tip (z)               18.308931   116.085587
# 3D keypoint: left_forepaw (x)           56.296429   161.135452
# 3D keypoint: left_forepaw (y)           71.564856   189.039978
# 3D keypoint: left_forepaw (z)            2.193133   117.557945
# 3D keypoint: right_forepaw (x)          55.577968   161.752579
# 3D keypoint: right_forepaw (y)          71.923119   189.020599
# 3D keypoint: right_forepaw (z)           1.787546   109.630981
# 3D keypoint: left_hindpaw_back (x)      55.344288   157.810287
# 3D keypoint: left_hindpaw_back (y)      69.106514   182.203506
# 3D keypoint: left_hindpaw_back (z)       3.042969    97.489746
# 3D keypoint: left_hindpaw_front (x)     55.581429   159.518173
# 3D keypoint: left_hindpaw_front (y)     71.364952   185.873764
# 3D keypoint: left_hindpaw_front (z)      1.583168    77.976982
# 3D keypoint: right_hindpaw_back (x)     55.758522   157.259689
# 3D keypoint: right_hindpaw_back (y)     66.537903   180.628464
# 3D keypoint: right_hindpaw_back (z)      2.789563    31.071239
# 3D keypoint: right_hindpaw_front (x)    53.698283   160.431625
# 3D keypoint: right_hindpaw_front (y)    67.368221   185.757385
# 3D keypoint: right_hindpaw_front (z)     1.544662   115.374039
# 2D keypoint: spine_low (x)             770.440048   1136.55188
# 2D keypoint: spine_low (y)             763.790543   995.723816
# 2D keypoint: tail_base (x)             776.953674  1155.198486
# 2D keypoint: tail_base (y)             768.980484   995.792603
# object bbox: object4 (y1)     0.880917
# object bbox: object4 (x1)     0.880917
# object bbox: object4 (y2)     0.880917
# object bbox: object4 (x2)     0.880917
# object bbox: object3 (y1)     0.736010
# object bbox: object3 (x1)     0.736010
# object bbox: object3 (y2)     0.736010
# object bbox: object3 (x2)     0.736010
# object bbox: object2 (y1)     0.544336
# object bbox: object2 (x1)     0.544336
# object bbox: object2 (y2)     0.544336
# object bbox: object2 (x2)     0.544336
# object bbox: object1 (y1)     0.363232
# object bbox: object1 (x1)     0.363232
# object bbox: object1 (y2)     0.363232
# object bbox: object1 (x2)     0.363232
# object bbox: object0 (y1)     0.195892
# object bbox: object0 (x1)     0.195892
# object bbox: object0 (y2)     0.195892
# object bbox: object0 (x2)     0.195892
# shMoSeq state                 0.071581
# session                       0.000000
# 3D keypoint: spine_low (z)    0.000000
# 3D keypoint: tail_base (x)    0.000000
# 3D keypoint: tail_base (y)    0.000000
# 3D keypoint: tail_base (z)    0.000000
# timestamp                     0.000000
# MoSeq syllable                0.000000
# 3D keypoint: spine_low (x)    0.000000
# 3D keypoint: spine_low (y)    0.000000
# dtype: float64
# H5 structure:
# DATASET: subject0_recording0, shape=(432017, 252), dtype=float32
# DATASET: subject0_recording1, shape=(432017, 105), dtype=float32
# DATASET: subject10_recording1, shape=(432017, 85), dtype=float32
# DATASET: subject10_recording2, shape=(432017, 58), dtype=float32
# DATASET: subject1_recording0, shape=(432017, 92), dtype=float32
# DATASET: subject2_recording0, shape=(432017, 321), dtype=float32
# DATASET: subject3_recording0, shape=(432017, 134), dtype=float32
# DATASET: subject4_recording0, shape=(432017, 141), dtype=float32
# DATASET: subject5_recording1, shape=(432017, 193), dtype=float32
# DATASET: subject6_recording0, shape=(432017, 199), dtype=float32
# DATASET: subject6_recording1, shape=(432017, 201), dtype=float32
# DATASET: subject6_recording2, shape=(432017, 125), dtype=float32
# DATASET: subject7_recording0, shape=(432017, 129), dtype=float32
# DATASET: subject8_recording0, shape=(432017, 136), dtype=float32
# DATASET: subject8_recording1, shape=(432017, 155), dtype=float32
# DATASET: subject9_recording0, shape=(432017, 115), dtype=float32
# DATASET: subject9_recording1, shape=(432017, 213), dtype=float32
# DATASET: subject9_recording2, shape=(432017, 145), dtype=float32
